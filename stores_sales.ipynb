# %%
import pandas as pd

from store_sales import CSVReader
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11,4),
    titlesize=18,
    titleweight="bold",
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)

# %%
oilCsv = CSVReader(read_path="data/oil.csv")
transactionsCsv = CSVReader(read_path='data/transactions.csv')

# %%
oilCsv.to_pandas()
transactionsCsv.to_pandas()

# %%
oilCsv.df.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
transactionsCsv.df.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
oilCsv.df.columns
# Out:
# Index(['date', 'dcoilwtico'], dtype='object')

# %%
oilCsv.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
import seaborn as sns
plt.plot(oilCsv.df['date'], oilCsv.df['dcoilwtico'])

# %%
from datetime import datetime

oilCsv.df['date'] = oilCsv.df['date'].map(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
oilCsv.df[['date','dcoilwtico']].set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>
